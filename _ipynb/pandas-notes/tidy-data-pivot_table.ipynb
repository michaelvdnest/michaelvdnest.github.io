# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.min_rows', 10)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# ### Year and month cross tabulation

# %%
df = pd.DataFrame(
   {"value": np.random.randn(36)},
   index=pd.date_range("2011-01-01", freq="M", periods=36),
)
df
# Out:
#                value
# 2011-01-31  1.631888
# 2011-02-28  0.912307
# 2011-03-31 -0.382308
# 2011-04-30 -0.807955
# 2011-05-31 -0.981323
# ...              ...
# 2013-08-31 -1.123876
# 2013-09-30 -0.085141
# 2013-10-31 -0.783807
# 2013-11-30 -1.049758
# 2013-12-31 -1.741065
#
# [36 rows x 1 columns]

# %%
pv = pd.pivot_table(
   df, index=df.index.month, columns=df.index.year, values="value", aggfunc="sum"
)

# %%
pv
# Out:
#         2011      2012      2013
# 1   1.631888 -0.628947 -0.209993
# 2   0.912307  0.917176  0.542608
# 3  -0.382308  0.016277  2.145662
# 4  -0.807955  0.994911  0.896891
# 5  -0.981323 -1.608848 -0.409535
# ..       ...       ...       ...
# 8  -0.086807  0.072927 -1.123876
# 9  -1.282145  2.157647 -0.085141
# 10  0.249420  0.462253 -0.783807
# 11 -0.588486 -1.130924 -1.049758
# 12 -1.404598 -0.761893 -1.741065
#
# [12 rows x 3 columns]

# %%
pv.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('sample_file_missing_data.csv', index_col='i')
df
# Out:
#      a    b    c
# i
# 1  7.0  NaN  7.0
# 2  NaN  6.0  3.0
# 3  4.0  4.0  NaN
# 4  8.0  NaN  5.0
# 5  1.0  4.0  4.0
# 6  5.0  NaN  NaN
# 7  7.0  6.0  3.0
# 8  NaN  6.0  6.0

# %%
df
# Out:
#      a    b    c
# i
# 1  7.0  NaN  7.0
# 2  NaN  6.0  3.0
# 3  4.0  4.0  NaN
# 4  8.0  NaN  5.0
# 5  1.0  4.0  4.0
# 6  5.0  NaN  NaN
# 7  7.0  6.0  3.0
# 8  NaN  6.0  6.0

# %% [markdown]
# #### Replace NA values with a value.

# %%
df.fillna(999)
# Out:
#        a      b      c
# i
# 1    7.0  999.0    7.0
# 2  999.0    6.0    3.0
# 3    4.0    4.0  999.0
# 4    8.0  999.0    5.0
# 5    1.0    4.0    4.0
# 6    5.0  999.0  999.0
# 7    7.0    6.0    3.0
# 8  999.0    6.0    6.0

# %% [markdown]
# #### Fill gaps forward

# %%
df.fillna(method ='ffill')
# Out:
#      a    b    c
# i
# 1  7.0  NaN  7.0
# 2  7.0  6.0  3.0
# 3  4.0  4.0  3.0
# 4  8.0  4.0  5.0
# 5  1.0  4.0  4.0
# 6  5.0  4.0  4.0
# 7  7.0  6.0  3.0
# 8  7.0  6.0  6.0

# %% [markdown]
# #### Fill gaps backwards.

# %%
df.fillna(method ='bfill')
# Out:
#      a    b    c
# i
# 1  7.0  6.0  7.0
# 2  4.0  6.0  3.0
# 3  4.0  4.0  5.0
# 4  8.0  4.0  5.0
# 5  1.0  4.0  4.0
# 6  5.0  6.0  3.0
# 7  7.0  6.0  3.0
# 8  NaN  6.0  6.0

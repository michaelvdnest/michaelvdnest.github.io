# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('sample_file_sort.csv')
df
# Out:
#    A  B  C    D
# 0  5  b  4  4.0
# 1  3  b  2  NaN
# 2  4  a  3  2.0
# 3  1  a  2  3.0
# 4  2  B  1  1.0

# %%
df
# Out:
#    A  B  C    D
# 0  5  b  4  4.0
# 1  3  b  2  NaN
# 2  4  a  3  2.0
# 3  1  a  2  3.0
# 4  2  B  1  1.0

# %% [markdown]
# ## Sort by one column

# %%
df.sort_values('A')
# Out:
#    A  B  C    D
# 3  1  a  2  3.0
# 4  2  B  1  1.0
# 1  3  b  2  NaN
# 2  4  a  3  2.0
# 0  5  b  4  4.0

# %% [markdown]
# ## Sort by more than one column

# %%
df.sort_values(by=['B', 'C'], ascending=[True, False])
# Out:
#    A  B  C    D
# 4  2  B  1  1.0
# 2  4  a  3  2.0
# 3  1  a  2  3.0
# 0  5  b  4  4.0
# 1  3  b  2  NaN

# %% [markdown]
# ## Sort by ignoring the index

# %%
df.sort_values('A', ignore_index=True)
# Out:
#    A  B  C    D
# 0  1  a  2  3.0
# 1  2  B  1  1.0
# 2  3  b  2  NaN
# 3  4  a  3  2.0
# 4  5  b  4  4.0

# %% [markdown]
# ## Sort by using key function

# %%
df.sort_values('B', key=lambda x: x.str.lower())
# Out:
#    A  B  C    D
# 2  4  a  3  2.0
# 3  1  a  2  3.0
# 0  5  b  4  4.0
# 1  3  b  2  NaN
# 4  2  B  1  1.0
